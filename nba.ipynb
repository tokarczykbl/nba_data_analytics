# %%
# Import Dependencies
import pandas as pd
import os
from unidecode import unidecode
from pathlib import Path
from pprint import pprint
# import matplotlib.pyplot as plt
# import numpy as np
# import hvplot.pandas
# from babel.numbers import format_currency
# from matplotlib.ticker import FuncFormatter

# %%
# Importing Cities, States and Countries files for prep and merge
# Cities Import
file_name = Path("data_downloads/Countries_States_Cities/cities.csv")
cities_df = pd.read_csv(file_name)

# Renaming Cities columns
cities_df = cities_df.rename(columns={"id":"city_id",
                                      "name":"city_name",
                                      "state_id":"state_id",
                                      "state_code":"state_code",
                                      "country_id":"country_id",
                                      "country_code":"country_code",
                                      "latitude":"city_latitude",
                                      "longitude":"city_longitude"
                                      })

#States Import
file_name = Path("data_downloads/Countries_States_Cities/states.csv")
states_df = pd.read_csv(file_name)

# Renaming States Columns
states_df = states_df.rename(columns={"id":"state_id",
                                      "name":"state_name",
                                      "country_id":"country_id",
                                      "country_code":"country_code",
                                      "state_code":"state_code",
                                      "latitude":"state_latitude",
                                      "longitude":"state_longitude",
                                      })

# Creating a list of columns need for merge from states_df
states_columns_needed = ['state_id','state_name', 'state_latitude', 'state_longitude']

#Countries Import
file_name = Path("data_downloads/Countries_States_Cities/countries.csv")
countries_df = pd.read_csv(file_name)

# Renaming countries columns
countries_df = countries_df.rename(columns={"id":"country_id",
                                            "name":"country_name",
                                            "iso3":"country_iso3",
                                            "iso2":"country_iso2",
                                            "phone_code":"country_phone_code",
                                            "capital":"country_capital",
                                            "currency":"country_currency",
                                            "currency_symbol":"country_currency_symbol",
                                            "tld":"country_tld",
                                            "native":"country_native",
                                            "region":"country_region",
                                            "subregion":"country_subregion",
                                            "timezones":"country_timezones",
                                            "latitude":"country_latitude",
                                            "longitude":"country_longitude",
                                            "emoji":"country_emoji",
                                            "emojiU":"country_emojiU"
                                            })

# Merging files and creating a single master dataframe
cities_states_df = pd.merge(cities_df, states_df[states_columns_needed], on='state_id', how='left')

cities_states_countries_df =  pd.merge(cities_states_df, countries_df, how='left', on='country_id')


cities_states_countries_master_df = cities_states_countries_df[['city_name', 'city_latitude', 'city_longitude',
                                                                'state_name', 'state_code', 'state_latitude', 'state_longitude',
                                                                'country_name', 'country_code', 'country_latitude', 'country_longitude',
                                                                'country_iso3',
                                                                'country_iso2',
                                                                'country_phone_code',
                                                                'country_capital',
                                                                'country_currency',
                                                                'country_currency_symbol',
                                                                'country_tld',
                                                                'country_native',
                                                                'country_region',
                                                                'country_subregion',
                                                                'country_timezones',
                                                                'country_emoji',
                                                                'country_emojiU']]

# Sorting columns and reseting index
cities_states_countries_master_df = cities_states_countries_master_df.sort_values(by=['country_region', 'country_subregion', 'country_name', 'state_name', 'city_name']).reset_index(drop=True)

cities_states_countries_master_df
# Saving a copy to csv
# cities_states_countries_master_df.to_csv("data_downloads/Countries_States_Cities/master_locations.csv")
# Out:
#               city_name  city_latitude  city_longitude  \
# 0               Bubanza       -3.08040        29.39100
# 1             Bujumbura       -3.38193        29.36142
# 2                Bururi       -3.94877        29.62438
# 3               Cankuzo       -3.21860        30.55280
# 4              Cibitoke       -2.88690        29.12480
# ...                 ...            ...             ...
# 147395    Kulia Village       -6.10819       177.33393
# 147396        Niulakita      -10.78800       179.46600
# 147397  Tanrake Village       -7.24562       177.14511
# 147398   Savave Village       -8.02731       178.31351
# 147399     Asau Village       -7.49026       178.68016
#
#                        state_name state_code  state_latitude  state_longitude  \
# 0                Bubanza Province         BB       -3.157240        29.371491
# 1       Bujumbura Mairie Province         BM       -3.388414        29.348265
# 2                 Bururi Province         BR       -3.900685        29.510771
# 3                Cankuzo Province         CA       -3.152779        30.619989
# 4               Cibitoke Province         CI       -2.810290        29.185578
# ...                           ...        ...             ...              ...
# 147395      Niutao Island Council        NIT       -6.106426       177.343843
# 147396      Niutao Island Council        NIT       -6.106426       177.343843
# 147397                        Nui        NUI       -7.238877       177.148523
# 147398                  Nukufetau        NKF       -8.000000       178.500000
# 147399                    Vaitupu        VAI       -7.476733       178.674768
#
#        country_name country_code  country_latitude  ...  country_capital  \
# 0           Burundi           BI              -3.5  ...        Bujumbura
# 1           Burundi           BI              -3.5  ...        Bujumbura
# 2           Burundi           BI              -3.5  ...        Bujumbura
# 3           Burundi           BI              -3.5  ...        Bujumbura
# 4           Burundi           BI              -3.5  ...        Bujumbura
# ...             ...          ...               ...  ...              ...
# 147395       Tuvalu           TV              -8.0  ...         Funafuti
# 147396       Tuvalu           TV              -8.0  ...         Funafuti
# 147397       Tuvalu           TV              -8.0  ...         Funafuti
# 147398       Tuvalu           TV              -8.0  ...         Funafuti
# 147399       Tuvalu           TV              -8.0  ...         Funafuti
#
#        country_currency country_currency_symbol country_tld country_native  \
# 0                   BIF                     FBu         .bi        Burundi
# 1                   BIF                     FBu         .bi        Burundi
# 2                   BIF                     FBu         .bi        Burundi
# 3                   BIF                     FBu         .bi        Burundi
# 4                   BIF                     FBu         .bi        Burundi
# ...                 ...                     ...         ...            ...
# 147395              AUD                       $         .tv         Tuvalu
# 147396              AUD                       $         .tv         Tuvalu
# 147397              AUD                       $         .tv         Tuvalu
# 147398              AUD                       $         .tv         Tuvalu
# 147399              AUD                       $         .tv         Tuvalu
#
#        country_region country_subregion  \
# 0              Africa    Eastern Africa
# 1              Africa    Eastern Africa
# 2              Africa    Eastern Africa
# 3              Africa    Eastern Africa
# 4              Africa    Eastern Africa
# ...               ...               ...
# 147395        Oceania         Polynesia
# 147396        Oceania         Polynesia
# 147397        Oceania         Polynesia
# 147398        Oceania         Polynesia
# 147399        Oceania         Polynesia
#
#                                         country_timezones country_emoji  \
# 0       [{zoneName:'Africa\/Bujumbura',gmtOffset:7200,...            🇧🇮
# 1       [{zoneName:'Africa\/Bujumbura',gmtOffset:7200,...            🇧🇮
# 2       [{zoneName:'Africa\/Bujumbura',gmtOffset:7200,...            🇧🇮
# 3       [{zoneName:'Africa\/Bujumbura',gmtOffset:7200,...            🇧🇮
# 4       [{zoneName:'Africa\/Bujumbura',gmtOffset:7200,...            🇧🇮
# ...                                                   ...           ...
# 147395  [{zoneName:'Pacific\/Funafuti',gmtOffset:43200...            🇹🇻
# 147396  [{zoneName:'Pacific\/Funafuti',gmtOffset:43200...            🇹🇻
# 147397  [{zoneName:'Pacific\/Funafuti',gmtOffset:43200...            🇹🇻
# 147398  [{zoneName:'Pacific\/Funafuti',gmtOffset:43200...            🇹🇻
# 147399  [{zoneName:'Pacific\/Funafuti',gmtOffset:43200...            🇹🇻
#
#          country_emojiU
# 0       U+1F1E7 U+1F1EE
# 1       U+1F1E7 U+1F1EE
# 2       U+1F1E7 U+1F1EE
# 3       U+1F1E7 U+1F1EE
# 4       U+1F1E7 U+1F1EE
# ...                 ...
# 147395  U+1F1F9 U+1F1FB
# 147396  U+1F1F9 U+1F1FB
# 147397  U+1F1F9 U+1F1FB
# 147398  U+1F1F9 U+1F1FB
# 147399  U+1F1F9 U+1F1FB
#
# [147400 rows x 24 columns]
